# %% [markdown]
# <a href="https://colab.research.google.com/github/zain4cs/ML_Pipelines/blob/main/predict_without_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('/content/drive/MyDrive/Datasets/ohe_sex.pkl', 'rb'))
ohe_Embarked = pickle.load(open('/content/drive/MyDrive/Datasets/ohe_Embarked.pkl', 'rb'))
clf = pickle.load(open('/content/drive/MyDrive/Datasets/clf.pkl','rb'))

# %%
# Assum User Input
# Pclass | Sex | Age	| SibSp |	Parch |	Fare |	Embarked

test_input = np.array([1,	'male',	45.5,	0,	0,	28.5000,	'S'], dtype=object).reshape(1,7)
test_input
# Out:
# array([[1, 'male', 45.5, 0, 0, 28.5, 'S']], dtype=object)

# %% [markdown]
# ______

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %% [markdown]
# ________________________________________

# %%
test_input_Embarked  = ohe_Embarked.transform(test_input[:,-1].reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_Embarked
# Out:
# array([[0., 0., 1., 0.]])

# %% [markdown]
# _______________________

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input_age , test_input_sex , test_input_Embarked , test_input[:,[0,3,4,5]]), axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 11)

# %%
clf.predict(test_input_transformed)
# Out:
# array([0])
